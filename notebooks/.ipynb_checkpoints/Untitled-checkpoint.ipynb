# %%
# %load_ext autoreload

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import sys
sys.path.append('../src/')

# %%
import geocode
# Out:
# Tokyo
# [35.6764225, 139.650027]
# New York
# [40.7127753, -74.0059728]
# Mexico City
# [19.4326077, -99.133208]
# Mumbai
# [18.9581934, 72.8320729]
# Sao Paulo
# [-23.5557714, -46.6395571]
# Delhi
# [28.7040592, 77.10249019999999]
# Shanghai
# [31.230416, 121.473701]
# Kolkata
# [22.5743545, 88.3628734]
# Dhaka
# [23.804093, 90.4152376]
# Buenos Aires
# [-34.6036739, -58.3821215]
# Los Angeles
# [34.0549076, -118.242643]
# Karachi
# [24.8607343, 67.0011364]
# Cairo
# [30.0444196, 31.2357116]
# Rio de Janeiro
# [-22.9068467, -43.1728965]
# Osaka
# [34.6937249, 135.5022535]
# Beijing
# [39.904211, 116.407395]
# Manila
# [14.5995133, 120.984234]
# Moscow
# [55.7568721, 37.6150527]
# Istanbul
# [41.0082376, 28.9783589]
# Paris
# [48.8575475, 2.3513765]
# Seoul
# [37.550263, 126.9970831]
# Lagos
# [6.613739499999999, 3.3552568]
# Jakarta
# [-6.1944491, 106.8229198]
# Chicago
# [41.88325, -87.6323879]
# Guangzhou
# [23.1290799, 113.26436]
# London
# [51.5072178, -0.1275862]
# Lima
# [-12.0466888, -77.04308859999999]
# Tehran
# [35.7218583, 51.3346954]
# Kinshasa
# [-4.3032527, 15.310528]
# Bogota
# [4.710988599999999, -74.072092]
# Shenzhen
# [22.5428599, 114.05956]
# Wuhan
# [30.5927599, 114.30525]
# Hong Kong
# [22.3193039, 114.1693611]
# Tianjin
# [39.085099, 117.199369]
# Chennai
# [13.0843007, 80.2704622]
# Taipei
# [25.0329636, 121.5654268]
# Bengaluru
# [12.9628669, 77.57750899999999]
# Bangkok
# [13.7563309, 100.5017651]
# Lahore
# [31.5203696, 74.35874729999999]
# Chongqing
# [29.5656843, 106.5511838]
#            city_name           country                  adm0name   pop_max  \
# 7332           Tokyo             Japan                     Japan  35676000
# 7317        New York     United States  United States of America  19040000
# 7323     Mexico City            Mexico                    Mexico  19028000
# 7333          Mumbai             India                     India  18978000
# 7338       Sao Paulo            Brazil                    Brazil  18845000
# 7241           Delhi             India                     India  15926000
# 7331        Shanghai             China                     China  14987000
# 7336         Kolkata             India                     India  14787000
# 7268           Dhaka        Bangladesh                Bangladesh  12797394
# 7309    Buenos Aires         Argentina                 Argentina  12795000
# 7315     Los Angeles     United States  United States of America  12500000
# 7188         Karachi          Pakistan                  Pakistan  12130000
# 7330           Cairo             Egypt                     Egypt  11893000
# 7337  Rio de Janeiro            Brazil                    Brazil  11748000
# 7299           Osaka             Japan                     Japan  11294000
# 7326         Beijing             China                     China  11106000
# 7294          Manila       Philippines               Philippines  11100000
# 7322          Moscow            Russia                    Russia  10452000
# 7319        Istanbul            Turkey                    Turkey  10061000
# 7334           Paris   French Republic                    France   9904000
# 7293           Seoul      Korea, South               South Korea   9796000
# 7324           Lagos           Nigeria                   Nigeria   9466000
# 7328         Jakarta         Indonesia                 Indonesia   9125000
# 7279         Chicago     United States  United States of America   8990000
# 7208       Guangzhou             China                     China   8829000
# 7318          London    United Kingdom            United Kingdom   8567000
# 7288            Lima              Peru                      Peru   8012000
# POINT (-99.1329341 19.4443883)
# 72.8758393972653
# POINT (72.8758393972653 19.06840847529168)
# -46.6269658
# POINT (-46.6269658 -23.5567337)
# 77.2280582
# POINT (77.2280582 28.6719388)
# 121.4345588
# POINT (121.4345588 31.2183983)
# 88.36912550443886
# POINT (88.36912550443886 22.569578883795778)
# 90.4066336
# POINT (90.4066336 23.7250056)
# -58.43251268766426
# POINT (-58.43251268766426 -34.61071459139255)
# -118.23198647223317
# POINT (-118.23198647223317 34.049219260337075)
# 66.9880631
# POINT (66.9880631 24.8719381)
# 31.2480224
# POINT (31.2480224 30.0519062)
# -43.212117466834385
# POINT (-43.212117466834385 -22.907308056882364)
# 135.50375419006232
# POINT (135.50375419006232 34.691095244477914)
# 116.39420089260611
# POINT (116.39420089260611 39.901720309862675)
# 120.9802713
# POINT (120.9802713 14.6061048)
# 37.613577
# POINT (37.613577 55.75411)
# 28.97427681675554
# POINT (28.97427681675554 41.01760173507249)
# 2.3529924615392135
# POINT (2.3529924615392135 48.85809231626911)
# 126.9977851
# POINT (126.9977851 37.568295)
# 3.3895852
# POINT (3.3895852 6.4452075)
# 106.8274918
# POINT (106.8274918 -6.1724718)
# -87.63523655322338
# POINT (-87.63523655322338 41.847961283364114)
# 113.26178516712943
# POINT (113.26178516712943 23.12472343296695)
# -0.1186677
# POINT (-0.1186677 51.5019406)
# -77.052008
# POINT (-77.052008 -12.0460668)
# 51.4223982
# POINT (51.4223982 35.6738886)
# 15.313026
# POINT (15.313026 -4.3277782)
# -74.0852898
# POINT (-74.0852898 4.5983694)
# 114.06115351896277
# POINT (114.06115351896277 22.54809707412332)
# 114.2680712
# POINT (114.2680712 30.5819772)
# 114.1830635
# POINT (114.1830635 22.3069268)
# 117.19660728208831
# POINT (117.19660728208831 39.08277176197969)
# 80.2780529
# POINT (80.2780529 13.0919337)
# 121.5683333
# POINT (121.5683333 25.0358333)
# 77.5580639
# POINT (77.5580639 12.971941)
# 100.5146988
# POINT (100.5146988 13.7519451)
# 74.3480789
# POINT (74.3480789 31.5619174)
# 106.5930358
# POINT (106.5930358 29.5669229)

# %%
import openmeteo_requests

import sys
import pandas as pd
import geopandas as gpd
import fiona
import requests_cache
from retry_requests import retry
import datetime

from geocode import geocoded_cities_pipeline

# %%
cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://archive-api.open-meteo.com/v1/archive"

# %%
cities_gdf = geocoded_cities_pipeline()

# %%
cities_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
df_cloud_cities_data_full = pd.DataFrame(columns=['date', 'cloud_cover'])
dict_cloud_cities_data_full = {}

# %%
for idx in cities_gdf.index:
    
    while idx < 4:
        
        
     

        print("idx")

        print(idx)

        geom = cities_gdf.at[idx, 'geometry']
        print(geom)

        print(cities_gdf.at[idx, 'city_name'])

        print(x_coord)
        x_coord = geom.x

        print(y_coord)    
        y_coord = geom.y

        params = {

            "latitude": y_coord,    # y coord
            "longitude": x_coord,  # x coord
            "start_date": "2022-10-04",
            "end_date": "2022-10-10",
            "hourly": ["cloud_cover"],
        }
        responses = openmeteo.weather_api(url, params=params)

        # Process first location. Add a for-loop for multiple locations or weather models
        response = responses[0]
        # print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
        # print(f"Elevation: {response.Elevation()} m asl")
        # print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")

        # Process hourly data. The order of variables needs to be the same as requested.  ##### XXX Note that the .Daily endpoint of the open-meteo API does NOT return cloud_cover information
        hourly = response.Hourly()
        print(hourly)
        hourly_cloud_cover = hourly.Variables(0).ValuesAsNumpy()
    #     hourly_cloud_cover_low = hourly.Variables(1).ValuesAsNumpy()
    #     hourly_cloud_cover_mid = hourly.Variables(2).ValuesAsNumpy()
    #     hourly_cloud_cover_high = hourly.Variables(3).ValuesAsNumpy()

        hourly_data = {"date": pd.date_range(
            start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
            end =  pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
            freq = pd.Timedelta(seconds = hourly.Interval()),
            inclusive = "left"
        )}

        hourly_data["cloud_cover"] = hourly_cloud_cover
    #     hourly_data["cloud_cover_low"] = hourly_cloud_cover_low
    #     hourly_data["cloud_cover_mid"] = hourly_cloud_cover_mid
    #     hourly_data["cloud_cover_high"] = hourly_cloud_cover_high

        hourly_dataframe_temp = pd.DataFrame(data = hourly_data)

        print("\nHourly data\n", hourly_dataframe)

        df_datetime_temp = hourly_dataframe_temp

        df_cloud_temp = df_datetime_temp.set_index('date').resample(rule='24h').mean()

        df_cloud_temp = df_cloud_temp.reset_index()

        df_cloud_temp = df_cloud_temp.set_index(df_cloud_temp.columns[0]).transpose()

        df_cities_temp = cities_gdf.head(idx +1)

        #print(temp_df)

        df_merged_temp = pd.merge(df_cities_temp, df_cloud_temp, how="cross")

        print(df_merged_temp)

        #hourly_dict = hourly_dataframe.to_dict('index')
# Out:
# idx
# 0
# POINT (139.7494616 35.6869628)
# Tokyo
# 139.7494616
# 35.6869628
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 40
#      34 response = responses[0]
#      35 # print(f"Coordinates: {response.Latitude()}°N {response.Longitude()}°E")
#      36 # print(f"Elevation: {response.Elevation()} m asl")
#      37 # print(f"Timezone difference to GMT+0: {response.UtcOffsetSeconds()}s")
#      38
#      39 # Process hourly data. The order of variables needs to be the same as requested.  ##### XXX Note that the .Daily endpoint of the open-meteo API does NOT return cloud_cover information
# ---> 40 hourly = response.Hourly()
#      41 print(hourly)
#      42 hourly_cloud_cover = hourly.Variables(0).ValuesAsNumpy()
#
# File ~/envs/.geospatial/lib/python3.11/site-packages/openmeteo_sdk/WeatherApiResponse.py:116, in WeatherApiResponse.Hourly(self)
#     115 def Hourly(self) -> Optional[VariablesWithTime]:
# --> 116     o = flatbuffers.number_types.UOffsetTFlags.py_type(self._tab.Offset(26))
#     117     if o != 0:
#     118         x = self._tab.Indirect(o + self._tab.Pos)
#
# File ~/envs/.geospatial/lib/python3.11/site-packages/flatbuffers/table.py:40, in Table.Offset(self, vtableOffset)
#      34 """Offset provides access into the Table's vtable.
#      35
#      36 Deprecated fields are ignored by checking the vtable's length.
#      37 """
#      39 vtable = self.Pos - self.Get(N.SOffsetTFlags, self.Pos)
# ---> 40 vtableEnd = self.Get(N.VOffsetTFlags, vtable)
#      41 if vtableOffset < vtableEnd:
#      42   return self.Get(N.VOffsetTFlags, vtable + vtableOffset)
#
# File ~/envs/.geospatial/lib/python3.11/site-packages/flatbuffers/table.py:100, in Table.Get(self, flags, off)
#      95 def Get(self, flags, off):
#      96   """Get retrieves a value of the type specified by `flags`  at the
#      97
#      98   given offset.
#      99   """
# --> 100   N.enforce_number(off, N.UOffsetTFlags)
#     101   return flags.py_type(encode.Get(flags.packer_type, self.Bytes, off))
#
# File ~/envs/.geospatial/lib/python3.11/site-packages/flatbuffers/number_types.py:151, in enforce_number(n, flags)
#     149   return
#     150 if not flags.min_val <= n <= flags.max_val:
# --> 151   raise TypeError("bad number %s for type %s" % (str(n), flags.name))
#
# TypeError: bad number -2752488 for type uint32
